# %%
import cPickle as pickle
from sklearn.feature_extraction.text import TfidfVectorizer, HashingVectorizer, CountVectorizer
from string import punctuation
import xgboost as xgb

from sklearn.preprocessing import label_binarize
from sklearn.cross_validation import train_test_split

from sklearn.metrics import roc_auc_score, roc_curve, classification_report, auc

from nltk import word_tokenize
from nltk.stem.snowball import SnowballStemmer

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#%matplotlib notebook
# %matplotlib inline

# %%
# See nice example from 
# https://github.com/dmlc/xgboost/blob/master/demo/multiclass_classification/train.py

# Also RunMutliclassOneVRest

# %% [markdown]
# ### Function Definitions

# %%
#from http://stackoverflow.com/questions/26126442/combining-text-stemming-and-removal-of-punctuation-in-nltk-and-scikit-learn


stemmer = SnowballStemmer("english")

def stem_tokens(tokens, stemmer):
    stemmed=[]
    for item in tokens:
        
        stemmed.append(stemmer.stem(item))
    return stemmed

def tokenize(text):
    tokens = word_tokenize(text)
    stems = stem_tokens(tokens, stemmer)
    return stems

# %%
# write function to grab the feature importances & show top ~20

def top_features(d, n=20):
    '''
    Function to show the top n important features & their scores.
    The get_fscore method in xgboost returns a dictionary of features & a number.
    Get the top n features with the highest scores
    
    d is a dictionary (from get_fscore method in xgboost)
    '''
    
    featureslist = []
    
    for k, v in sorted(d.iteritems(), reverse=True, key=lambda (k,v): (v,k)):
        featureslist.append((k,v))
    
    return featureslist[:n]

# %%
# write function to grab the feature importances & show top ~20

def top_features_words(d,vect, n=20):
    '''
    Function to show the top n important features, their scores,and corresponding words.
    The get_fscore method in xgboost returns a dictionary of features & a number.
    Get the top n features with the highest scores
    
    d is a dictionary (from bst.get_fscore() in xgboost)
    vect is the instantiated vectorizer (e.g. vect = TfidfVectorizer(stuff); not the fitted variable name)
    '''
    
    # Back out important features

    dicta = vect.vocabulary_
    dictb = dict ( (v,k) for k, v in dicta.items() )
    # dictb[featurenum] returns the word.

    featureslist = []
    for k, v in sorted(d.iteritems(), reverse=True, key=lambda (k,v): (v,k)):
        featureslist.append((k,v))
    
    topfeatures = []
    for i in xrange(n):
        fname = featureslist[i][0]
        fnum=int(filter(lambda x: x.isdigit(),fname))
        topfeatures.append((featureslist[i][0],featureslist[i][1],dictb[fnum]))
    
    return topfeatures

# %%
def createmulticlassROC(classes, y_test, y_score):
    '''
    Function to create & plot ROC curve & associated areas
    Adapted from http://scikit-learn.org/stable/auto_examples/model_selection/plot_roc.html

    Inputs: classes: a list of classes
            y_test: the test labels, binarized into columns
            y_score: the predicted probabilities for each class.   
                (e.g. y_score = classifier.fit(countv_fit_X_train, y_train).predict_proba(countv_fit_X_test) )
    '''
    
    # Compute ROC curve and ROC area for each class
    n_classes = len(classes)
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_score[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    # Plot all ROC curves
    plt.figure(figsize = (12,8))

    for i in range(n_classes):
        plt.plot(fpr[i], tpr[i], label='ROC curve of class {0} (area = {1:0.2f})'
                                       ''.format(classes[i], roc_auc[i]))

    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curves for Predicting Hate Speech')
    plt.legend(loc="lower right")
    plt.show()

# %% [markdown]
# ### Load Data

# %%
X_stripped = pickle.load(open('../Data/X_stripped.p', 'rb'))
y = pickle.load(open('../Data/y.p', 'rb'))
# X = pickle.load(open('../Data/X.p', 'rb'))

# %%
### Load & Save out

# # Load data
# df = pickle.load(open('../Data/labeledhate_5cats.p', 'rb'))
# X = df.body
# # use apply fuction to strip puctuation from X
# X_stripped = X.apply(lambda x: ''.join([l for l in x if l not in punctuation]))
# y = df.label
# #Save out just X, X_stripped & y
# pickle.dump(X, open('../Data/X.p', 'wb'))
# pickle.dump(X_stripped, open('../Data/X_stripped.p', 'wb'))
# pickle.dump(y, open('../Data/y.p', 'wb'))

# %%
classes=['NotHate', 'SizeHate', 'GenderHate', 'RaceHate', 'ReligionHate']
n_classes = len(classes)

# %%
# Relabel the output, integers [0-4], for xgboost
# e.g. for 0: df.ix[(df.label=='NotHate'),'label'] = '0'

for ind in range(len(classes)):
    y[(y==classes[ind])] = int(ind)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_stripped, y, test_size=0.3, random_state=42)

# %%
# Binarize ylabel (y_test), so we can call multiclass roc plot
# Need to cast y_test as an int.
ylabel_bin = label_binarize(y_test.astype(int), classes=[0,1,2,3,4],sparse_output=False)

# %% [markdown]
# ### End Load Data

# %%
# Had some problems with label_binarize--wanted to probe type_of_target in this cell to see if that was the issue
# (It was.)
from sklearn.utils.multiclass import type_of_target
type_of_target(y_test.astype(int))
# Out:
# 'multiclass'

# %%
np.array(y_test).shape
# Out:
# (473426,)

# %%
# y_test

# %% [markdown]
# #### Use Count Vectorizer

# %%
# Model notes:
#  CV with 10,000 features, no tokenizing, english stop words --> AUC = 0.644
#  CV with 20,000 features, no tokenizing, english stop words --> AUC = 0.644
#  CV with 5,000 features, no tokenizing, english stop words --> AUC = 0.642
#  CV with 5,000 features, no tokenizing, english stop words, eta = 0.3 --> 0.666
#  CV with 5,000 features, no tokenizing, english stop words, eta = 0.9 --> 0.710
# Assuming english stop words
#  CV with 5,000 features, no tokenizing, max_depth = 4 , eta = 0.9 --> 0.687  (stick to max depth = 6)

# %%
countv = CountVectorizer(decode_error = 'ignore', stop_words = 'english',max_features=5000, tokenizer=None)
# countv = CountVectorizer(decode_error = 'ignore', stop_words = 'english', max_features=5000, tokenizer=None)

# %%
#Training vectors
countv_fit_X_train = countv.fit_transform(X_train)
#test vectora
countv_fit_X_test = countv.transform(X_test)

# %%
y_train.value_counts()
# Out:
# 0    708151
# 1    222053
# 2    133035
# 3     37368
# 4      4052
# Name: label, dtype: int64

# %%
xg_train = xgb.DMatrix(countv_fit_X_train, label=y_train)
xg_test = xgb.DMatrix(countv_fit_X_test, label=y_test)

# %%
# Set up xboost parameters
param = {}
# use softmax multi-class classification
param['objective'] = 'multi:softmax'
# scale weight of positive examples
param['eta'] = 0.9
param['max_depth'] = 4
param['silent'] = 1
param['nthread'] = 4
param['num_class'] = 5


watchlist = [ (xg_train, 'train'), (xg_test, 'test') ]
num_round = 5
bst = xgb.train(param, xg_train, num_round, watchlist );
# get prediction
pred = bst.predict( xg_test );

# #reshape y_test
# ytestlen = y_test.shape[0]
# y_test.reshape( ytestlen, 1 )

print ('predicting, classification error=%f' % (sum( int(pred[i]) != y_test.iloc[i] for i in range(len(y_test))) / float(len(y_test)) ))
# Out:
# [0]	train-merror:0.314597	test-merror:0.312704
# [1]	train-merror:0.307330	test-merror:0.305186
# [2]	train-merror:0.300204	test-merror:0.298412
# [3]	train-merror:0.295704	test-merror:0.293991
# predicting, classification error=0.291256
# [4]	train-merror:0.292797	test-merror:0.291256

# %%
# do the same thing again, but output probabilities
param['objective'] = 'multi:softprob'
bst = xgb.train(param, xg_train, num_round, watchlist );
# Note: this convention has been changed since xgboost-unity
# get prediction, this is in 1D array, need reshape to (ndata, nclass)
yprob = bst.predict( xg_test ).reshape( y_test.shape[0], 5 )
ylabel = np.argmax(yprob, axis=1)

print ('predicting, classification error=%f' % (sum( int(ylabel[i]) != y_test.iloc[i] for i in range(len(y_test))) / float(len(y_test)) ))
# Out:
# [0]	train-merror:0.314597	test-merror:0.312704
# [1]	train-merror:0.307330	test-merror:0.305186
# [2]	train-merror:0.300204	test-merror:0.298412
# [3]	train-merror:0.295704	test-merror:0.293991
# predicting, classification error=0.291256
# [4]	train-merror:0.292797	test-merror:0.291256

# %%
createmulticlassROC(classes, ylabel_bin, yprob)
print("average AUC: {0}").format(roc_auc_score(ylabel_bin, yprob))
# Out:
# <img src="data:image/png;base64,...">
# average AUC: 0.687091573998

# %%
top_features(bst.get_fscore(), n=30)
# Out:
# [('f1726', 36),
#  ('f3263', 31),
#  ('f4890', 24),
#  ('f2051', 21),
#  ('f4923', 15),
#  ('f2659', 14),
#  ('f1975', 14),
#  ('f3034', 13),
#  ('f1935', 12),
#  ('f1933', 12),
#  ('f1931', 12),
#  ('f1734', 12),
#  ('f539', 11),
#  ('f4872', 11),
#  ('f3033', 11),
#  ('f2482', 11),
#  ('f2480', 11),
#  ('f540', 10),
#  ('f507', 10),
#  ('f1907', 10),
#  ('f1391', 10),
#  ('f4891', 9),
#  ('f4638', 9),
#  ('f4106', 9),
#  ('f2515', 9),
#  ('f1763', 9),
#  ('f4524', 8),
#  ('f682', 6),
#  ('f4107', 6),
#  ('f3912', 6)]

# %% [markdown]
# ### Use TF-IDF

# %%
# Model notes
#  TFIDF with english stop words, 10,000 features, no tokenizing --> avg AUC = .6436
#  TFIDF with english stop words, 20,000 features, no tokenizing --> avg AUC = .6441
#  TFIDF with english stop words, 1000 features, no tokenizing --> avg AUC = .6349
#  TFIDF with english stop words, 50,000 features, no tokenizing --> avg AUC = .6447
#  TFIDF with english stop words, 5000 features, no tokenizing --> avg AUC = .6416
#  TFIDF with english stop words, 5000 features, no tokenizing, eta = 0.35 --> avg AUC = .676
#  TFIDF with english stop words, 5000 features, no tokenizing, eta = 0.4 --> avg AUC = .676
#  TFIDF with english stop words, 5000 features, no tokenizing, eta = 0.5 --> avg AUC = .685
#  TFIDF with english stop words, 5000 features, no tokenizing, eta = 0.7 --> avg AUC = .702
#  TFIDF with english stop words, 5000 features, no tokenizing, eta = 0.9 --> avg AUC = .712
#  TFIDF with english stop words, 10,000 features, no tokenizing, eta = 0.9 --> avg AUC = .715
#  TFIDF with english stop words, 5,000 features, WITH tokenizing/snowball, eta = 0.9 --> avg AUC = .735

#  TFIDF with english stop words, 5000 features, no tokenizing, eta = 0.95 --> avg AUC = .712 --> use eta=0.9

# %%
tfidfv = TfidfVectorizer(decode_error = 'ignore', stop_words = 'english', max_features=5000, tokenizer=None)

# %%
#Training vectors
tfidfv_fit_X_train = tfidfv.fit_transform(X_train)
#test vectors
tfidfv_fit_X_test = tfidfv.transform(X_test)

# %%
xg_train = xgb.DMatrix(tfidfv_fit_X_train, label=y_train)
xg_test = xgb.DMatrix(tfidfv_fit_X_test, label=y_test)
# Set up xboost parameters
param = {}
# use softmax multi-class classification
param['objective'] = 'multi:softmax'
# scale weight of positive examples
param['eta'] = 0.90
param['max_depth'] = 6
param['silent'] = 1
param['nthread'] = 4
param['num_class'] = 5


watchlist = [ (xg_train, 'train'), (xg_test, 'test') ]
num_round = 5
bst = xgb.train(param, xg_train, num_round, watchlist );
# get prediction
pred = bst.predict( xg_test );

# #reshape y_test
# ytestlen = y_test.shape[0]
# y_test.reshape( ytestlen, 1 )

print ('predicting, classification error=%f' % (sum( int(pred[i]) != y_test.iloc[i] for i in range(len(y_test))) / float(len(y_test)) ))
# do the same thing again, but output probabilities
param['objective'] = 'multi:softprob'
bst = xgb.train(param, xg_train, num_round, watchlist );
# Note: this convention has been changed since xgboost-unity
# get prediction, this is in 1D array, need reshape to (ndata, nclass)
yprob = bst.predict( xg_test ).reshape( y_test.shape[0], 5 )
ylabel = np.argmax(yprob, axis=1)

print ('predicting, classification error=%f' % (sum( int(ylabel[i]) != y_test.iloc[i] for i in range(len(y_test))) / float(len(y_test)) ))
# Out:
# [0]	train-merror:0.306409	test-merror:0.304884
# [1]	train-merror:0.298475	test-merror:0.297037
# [2]	train-merror:0.292203	test-merror:0.291006
# [3]	train-merror:0.287473	test-merror:0.286674
# [4]	train-merror:0.282943	test-merror:0.282747
# [0]	train-merror:0.306409	test-merror:0.304884
# [1]	train-merror:0.298475	test-merror:0.297037
# [2]	train-merror:0.292203	test-merror:0.291006
# [3]	train-merror:0.287473	test-merror:0.286674
# [4]	train-merror:0.282943	test-merror:0.282747
# predicting, classification error=0.282747
# predicting, classification error=0.282747

# %%
createmulticlassROC(classes, ylabel_bin, yprob)
print("average AUC: {0}").format(roc_auc_score(ylabel_bin, yprob))
# Out:
# <img src="data:image/png;base64,...">
# average AUC: 0.711991417256

# %%
top_features(bst.get_fscore(), n=30)
# Out:
# [('f1726', 18),
#  ('f3034', 12),
#  ('f2051', 12),
#  ('f4872', 10),
#  ('f2480', 10),
#  ('f4890', 8),
#  ('f1935', 8),
#  ('f1933', 8),
#  ('f3263', 7),
#  ('f3033', 7),
#  ('f1975', 7),
#  ('f1391', 7),
#  ('f2482', 6),
#  ('f1734', 6),
#  ('f1691', 6),
#  ('f1931', 5),
#  ('f540', 4),
#  ('f4891', 4),
#  ('f4106', 4),
#  ('f2711', 4),
#  ('f1907', 4),
#  ('f568', 3),
#  ('f507', 3),
#  ('f4923', 3),
#  ('f4524', 3),
#  ('f4042', 3),
#  ('f2848', 3),
#  ('f2437', 3),
#  ('f2230', 3),
#  ('f1945', 3)]

# %%
# %matplotlib notebook
#figure(figsize(12,8))
xgb.plot_importance(bst)
# Out:
# <img src="data:image/png;base64,...">

# %%
# Back out important features
dicta = tfidfv.vocabulary_
dictb = dict ( (v,k) for k, v in dicta.items() )
dictb[4872]  #put in the feature # here to get the word back

# %%
# Out:
# u'weight'

# %%
tfidfv = TfidfVectorizer(decode_error = 'ignore', stop_words = 'english', max_features=1000, tokenizer=tokenize)

#Training vectors
tfidfv_fit_X_train = tfidfv.fit_transform(X_train)
pickle.dump(tfidfv_fit_X_train, open('tfidf1000_fittrans_X_train.p', 'wb'))

#test vectora
tfidfv_fit_X_test = tfidfv.transform(X_test)
pickle.dump(tfidfv_fit_X_test, open('tfidf1000_fit_X_test.p', 'wb'))


xg_train = xgb.DMatrix(tfidfv_fit_X_train, label=y_train)
xg_test = xgb.DMatrix(tfidfv_fit_X_test, label=y_test)

# %%
# Set up xboost parameters
param = {}
# use softmax multi-class classification
param['objective'] = 'multi:softmax'
# scale weight of positive examples
param['eta'] = 0.90
param['max_depth'] = 6
param['silent'] = 1
# param['nthread'] = 4
param['num_class'] = 5


watchlist = [ (xg_train, 'train'), (xg_test, 'test') ]
num_round = 10

# output probabilities
param['objective'] = 'multi:softprob'
bst = xgb.train(param, xg_train, num_round, watchlist );
# Note: this convention has been changed since xgboost-unity
# get prediction, this is in 1D array, need reshape to (ndata, nclass)
yprob = bst.predict( xg_test ).reshape( y_test.shape[0], 5 )
ylabel = np.argmax(yprob, axis=1)

print ('predicting, classification error=%f' % (sum( int(ylabel[i]) != y_test.iloc[i] for i in range(len(y_test))) / float(len(y_test)) ))

createmulticlassROC(classes, ylabel_bin, yprob)
print("average AUC: {0}").format(roc_auc_score(ylabel_bin, yprob))
# Out:
# [0]	train-merror:0.305857	test-merror:0.304485
# [1]	train-merror:0.301198	test-merror:0.300288
# [2]	train-merror:0.296273	test-merror:0.295791
# [3]	train-merror:0.293085	test-merror:0.292975
# [4]	train-merror:0.290902	test-merror:0.291127
# [5]	train-merror:0.289348	test-merror:0.289914
# [6]	train-merror:0.288431	test-merror:0.289194
# [7]	train-merror:0.287221	test-merror:0.288239
# [8]	train-merror:0.286097	test-merror:0.287255
# [9]	train-merror:0.285170	test-merror:0.286442
# predicting, classification error=0.286442
# average AUC: 0.755420099775

# %%
top_features_words(bst.get_fscore(),tfidfv, n=20)
# Out:
# [('f15', 90, u','),
#  ('f18', 85, u'.'),
#  ('f355', 72, u'fat'),
#  ('f976', 45, u'white'),
#  ('f9', 45, u"'s"),
#  ('f625', 42, u'nigger'),
#  ('f674', 37, u'peopl'),
#  ('f614', 37, u"n't"),
#  ('f391', 36, u'game'),
#  ('f137', 36, u'black'),
#  ('f6', 33, u"''"),
#  ('f504', 32, u'jew'),
#  ('f39', 27, u'?'),
#  ('f542', 26, u'like'),
#  ('f385', 26, u'fuck'),
#  ('f968', 25, u'weight'),
#  ('f37', 21, u';'),
#  ('f982', 20, u'women'),
#  ('f636', 19, u'obes'),
#  ('f510', 19, u'just')]

# %%
# Set up xboost parameters
param = {}
# use softmax multi-class classification
param['objective'] = 'multi:softmax'
# scale weight of positive examples
param['eta'] = 0.90
param['max_depth'] = 6
param['silent'] = 1
# param['nthread'] = 4
param['num_class'] = 5


watchlist = [ (xg_train, 'train'), (xg_test, 'test') ]
num_round = 20

# output probabilities
param['objective'] = 'multi:softprob'
bst = xgb.train(param, xg_train, num_round, watchlist );
# Note: this convention has been changed since xgboost-unity
# get prediction, this is in 1D array, need reshape to (ndata, nclass)
yprob = bst.predict( xg_test ).reshape( y_test.shape[0], 5 )
ylabel = np.argmax(yprob, axis=1)

print ('predicting, classification error=%f' % (sum( int(ylabel[i]) != y_test.iloc[i] for i in range(len(y_test))) / float(len(y_test)) ))

createmulticlassROC(classes, ylabel_bin, yprob)
print("average AUC: {0}").format(roc_auc_score(ylabel_bin, yprob))

top_features_words(bst.get_fscore(),tfidfv, n=20)
# Out:
# [0]	train-merror:0.305857	test-merror:0.304485
# [1]	train-merror:0.301198	test-merror:0.300288
# [2]	train-merror:0.296273	test-merror:0.295791
# [3]	train-merror:0.293085	test-merror:0.292975
# [4]	train-merror:0.290902	test-merror:0.291127
# [5]	train-merror:0.289348	test-merror:0.289914
# [6]	train-merror:0.288431	test-merror:0.289194
# [7]	train-merror:0.287221	test-merror:0.288239
# [8]	train-merror:0.286097	test-merror:0.287255
# [9]	train-merror:0.285170	test-merror:0.286442
# [10]	train-merror:0.284536	test-merror:0.286049
# [11]	train-merror:0.283785	test-merror:0.285417
# [12]	train-merror:0.283344	test-merror:0.285130
# [13]	train-merror:0.282862	test-merror:0.284651
# [14]	train-merror:0.281811	test-merror:0.283785
# [15]	train-merror:0.281412	test-merror:0.283489
# [16]	train-merror:0.280688	test-merror:0.283009
# [17]	train-merror:0.279627	test-merror:0.282285
# [18]	train-merror:0.279210	test-merror:0.281981
# [19]	train-merror:0.278653	test-merror:0.281647
# predicting, classification error=0.281647
# average AUC: 0.776570542655
# [('f18', 206, u'.'),
#  ('f15', 182, u','),
#  ('f355', 108, u'fat'),
#  ('f9', 93, u"'s"),
#  ('f614', 86, u"n't"),
#  ('f39', 68, u'?'),
#  ('f674', 63, u'peopl'),
#  ('f976', 58, u'white'),
#  ('f542', 54, u'like'),
#  ('f6', 53, u"''"),
#  ('f391', 50, u'game'),
#  ('f625', 48, u'nigger'),
#  ('f137', 46, u'black'),
#  ('f385', 45, u'fuck'),
#  ('f504', 41, u'jew'),
#  ('f982', 40, u'women'),
#  ('f510', 40, u'just'),
#  ('f968', 38, u'weight'),
#  ('f636', 34, u'obes'),
#  ('f37', 30, u';')]

# %% [markdown]
# ### Started stripping punctuation here & below

# %%
tfidfv = TfidfVectorizer(decode_error = 'ignore', stop_words = 'english', max_features=1000, tokenizer=tokenize)

#Training vectors
tfidfv_fit_X_train = tfidfv.fit_transform(X_train)
pickle.dump(tfidfv_fit_X_train, open('tfidf1000_puncstrip_fittrans_X_train.p', 'wb'))

#test vectora
tfidfv_fit_X_test = tfidfv.transform(X_test)
pickle.dump(tfidfv_fit_X_test, open('tfidf1000_puncstrip_fit_X_test.p', 'wb'))


xg_train = xgb.DMatrix(tfidfv_fit_X_train, label=y_train)
xg_test = xgb.DMatrix(tfidfv_fit_X_test, label=y_test)

# %%
#Model XGBoost1000strip_80rounds

# Set up xboost parameters
param = {}
# use softmax multi-class classification
param['objective'] = 'multi:softmax'
# scale weight of positive examples
param['eta'] = 0.90
param['max_depth'] = 6
param['silent'] = 1
# param['nthread'] = 4
param['num_class'] = 5


watchlist = [ (xg_train, 'train'), (xg_test, 'test') ]
num_round = 80

# output probabilities
param['objective'] = 'multi:softprob'
bst = xgb.train(param, xg_train, num_round, watchlist );
# Note: this convention has been changed since xgboost-unity
# get prediction, this is in 1D array, need reshape to (ndata, nclass)
yprob = bst.predict( xg_test ).reshape( y_test.shape[0], 5 )
ylabel = np.argmax(yprob, axis=1)

print ('predicting, classification error=%f' % (sum( int(ylabel[i]) != y_test.iloc[i] for i in range(len(y_test))) / float(len(y_test)) ))

createmulticlassROC(classes, ylabel_bin, yprob)
print("average AUC: {0}").format(roc_auc_score(ylabel_bin, yprob))

top_features_words(bst.get_fscore(),tfidfv, n=20)
# Out:
# [0]	train-merror:0.307649	test-merror:0.306054
# [1]	train-merror:0.299728	test-merror:0.298532
# [2]	train-merror:0.296513	test-merror:0.295687
# [3]	train-merror:0.293568	test-merror:0.292964
# [4]	train-merror:0.291590	test-merror:0.291315
# [5]	train-merror:0.290261	test-merror:0.290322
# [6]	train-merror:0.289154	test-merror:0.289581
# [7]	train-merror:0.287757	test-merror:0.288189
# [8]	train-merror:0.286466	test-merror:0.286951
# [9]	train-merror:0.285662	test-merror:0.286140
# [10]	train-merror:0.285104	test-merror:0.285798
# [11]	train-merror:0.284043	test-merror:0.284989
# [12]	train-merror:0.283181	test-merror:0.284384
# [13]	train-merror:0.282704	test-merror:0.284104
# [14]	train-merror:0.282254	test-merror:0.283795
# [15]	train-merror:0.281811	test-merror:0.283499
# [16]	train-merror:0.281017	test-merror:0.282997
# [17]	train-merror:0.280110	test-merror:0.282145
# [18]	train-merror:0.279309	test-merror:0.281527
# [19]	train-merror:0.278806	test-merror:0.281094
# [20]	train-merror:0.278412	test-merror:0.280859
# [21]	train-merror:0.278065	test-merror:0.280623
# [22]	train-merror:0.277603	test-merror:0.280261
# [23]	train-merror:0.277198	test-merror:0.279902
# [24]	train-merror:0.276787	test-merror:0.279691
# [25]	train-merror:0.275949	test-merror:0.279112
# [26]	train-merror:0.275620	test-merror:0.278986
# [27]	train-merror:0.275299	test-merror:0.278812
# [28]	train-merror:0.274953	test-merror:0.278591
# [29]	train-merror:0.274764	test-merror:0.278487
# [30]	train-merror:0.274383	test-merror:0.278263
# [31]	train-merror:0.274181	test-merror:0.278130
# [32]	train-merror:0.273777	test-merror:0.277938
# [33]	train-merror:0.273461	test-merror:0.277784
# [34]	train-merror:0.273201	test-merror:0.277627
# [35]	train-merror:0.272901	test-merror:0.277524
# [36]	train-merror:0.272712	test-merror:0.277395
# [37]	train-merror:0.272298	test-merror:0.277196
# [38]	train-merror:0.272127	test-merror:0.277103
# [39]	train-merror:0.271961	test-merror:0.276947
# [40]	train-merror:0.271854	test-merror:0.277006
# [41]	train-merror:0.271597	test-merror:0.276827
# [42]	train-merror:0.271221	test-merror:0.276618
# [43]	train-merror:0.271003	test-merror:0.276556
# [44]	train-merror:0.270704	test-merror:0.276324
# [45]	train-merror:0.270487	test-merror:0.276185
# [46]	train-merror:0.270032	test-merror:0.275984
# [47]	train-merror:0.269848	test-merror:0.275889
# [48]	train-merror:0.269335	test-merror:0.275456
# [49]	train-merror:0.268899	test-merror:0.275084
# [50]	train-merror:0.268726	test-merror:0.275017
# [51]	train-merror:0.268364	test-merror:0.274782
# [52]	train-merror:0.268204	test-merror:0.274704
# [53]	train-merror:0.268059	test-merror:0.274731
# [54]	train-merror:0.267828	test-merror:0.274588
# [55]	train-merror:0.267660	test-merror:0.274560
# [56]	train-merror:0.267495	test-merror:0.274446
# [57]	train-merror:0.267224	test-merror:0.274273
# [58]	train-merror:0.267040	test-merror:0.274153
# [59]	train-merror:0.266854	test-merror:0.274077
# [60]	train-merror:0.266639	test-merror:0.273922
# [61]	train-merror:0.266449	test-merror:0.273806
# [62]	train-merror:0.266359	test-merror:0.273772
# [63]	train-merror:0.266210	test-merror:0.273711
# [64]	train-merror:0.265992	test-merror:0.273557
# [65]	train-merror:0.265827	test-merror:0.273399
# [66]	train-merror:0.265710	test-merror:0.273316
# [67]	train-merror:0.265620	test-merror:0.273246
# [68]	train-merror:0.265431	test-merror:0.273198
# [69]	train-merror:0.265291	test-merror:0.273132
# [70]	train-merror:0.265168	test-merror:0.273090
# [71]	train-merror:0.264951	test-merror:0.273094
# [72]	train-merror:0.264795	test-merror:0.273031
# [73]	train-merror:0.264436	test-merror:0.272847
# [74]	train-merror:0.264274	test-merror:0.272807
# [75]	train-merror:0.264244	test-merror:0.272839
# [76]	train-merror:0.263798	test-merror:0.272592
# [77]	train-merror:0.263674	test-merror:0.272520
# [78]	train-merror:0.263650	test-merror:0.272664
# [79]	train-merror:0.263380	test-merror:0.272539
# predicting, classification error=0.272539
# average AUC: 0.793541279946
# [('f656', 256, u'peopl'),
#  ('f524', 252, u'like'),
#  ('f491', 215, u'just'),
#  ('f329', 199, u'fat'),
#  ('f259', 169, u'dont'),
#  ('f359', 163, u'fuck'),
#  ('f972', 136, u'white'),
#  ('f447', 135, u'im'),
#  ('f87', 116, u'becaus'),
#  ('f977', 115, u'women'),
#  ('f548', 112, u'make'),
#  ('f903', 99, u'think'),
#  ('f365', 88, u'game'),
#  ('f107', 85, u'black'),
#  ('f962', 81, u'weight'),
#  ('f790', 81, u'say'),
#  ('f485', 81, u'jew'),
#  ('f685', 80, u'post'),
#  ('f275', 72, u'eat'),
#  ('f902', 65, u'thing')]

# %%
bst.save_model('XGBoost1000strip_80rounds.model')
#https://xgboost.readthedocs.org/en/latest/python/python_intro.html

# %%
# Set up xboost parameters
param = {}
# use softmax multi-class classification
param['objective'] = 'multi:softmax'
# scale weight of positive examples
param['eta'] = 0.5          #<<<---- THE MAIN DIFFERENCE FROM ABOVE
param['max_depth'] = 6
param['silent'] = 1
# param['nthread'] = 4
param['num_class'] = 5


watchlist = [ (xg_train, 'train'), (xg_test, 'test') ]
num_round = 40

# output probabilities
param['objective'] = 'multi:softprob'
bst = xgb.train(param, xg_train, num_round, watchlist );
# Note: this convention has been changed since xgboost-unity
# get prediction, this is in 1D array, need reshape to (ndata, nclass)
yprob = bst.predict( xg_test ).reshape( y_test.shape[0], 5 )
ylabel = np.argmax(yprob, axis=1)

print ('predicting, classification error=%f' % (sum( int(ylabel[i]) != y_test.iloc[i] for i in range(len(y_test))) / float(len(y_test)) ))

createmulticlassROC(classes, ylabel_bin, yprob)
print("average AUC: {0}").format(roc_auc_score(ylabel_bin, yprob))

top_features_words(bst.get_fscore(),tfidfv, n=20)
# Out:
# [0]	train-merror:0.307649	test-merror:0.306054
# [1]	train-merror:0.305380	test-merror:0.303952
# [2]	train-merror:0.300487	test-merror:0.299392
# [3]	train-merror:0.300786	test-merror:0.299745
# [4]	train-merror:0.299501	test-merror:0.298682
# [5]	train-merror:0.297790	test-merror:0.297058
# [6]	train-merror:0.296985	test-merror:0.296374
# [7]	train-merror:0.296281	test-merror:0.295791
# [8]	train-merror:0.295375	test-merror:0.295020
# [9]	train-merror:0.293839	test-merror:0.293395
# [10]	train-merror:0.292952	test-merror:0.292796
# [11]	train-merror:0.292250	test-merror:0.292320
# [12]	train-merror:0.291629	test-merror:0.291687
# [13]	train-merror:0.291302	test-merror:0.291382
# [14]	train-merror:0.290746	test-merror:0.291040
# [15]	train-merror:0.289872	test-merror:0.289931
# [16]	train-merror:0.289032	test-merror:0.289156
# [17]	train-merror:0.288526	test-merror:0.288717
# [18]	train-merror:0.287830	test-merror:0.288180
# [19]	train-merror:0.287530	test-merror:0.287918
# [20]	train-merror:0.286206	test-merror:0.286683
# [21]	train-merror:0.285431	test-merror:0.286043
# [22]	train-merror:0.284862	test-merror:0.285599
# [23]	train-merror:0.284682	test-merror:0.285506
# [24]	train-merror:0.284065	test-merror:0.284978
# [25]	train-merror:0.283167	test-merror:0.284279
# [26]	train-merror:0.282749	test-merror:0.283878
# [27]	train-merror:0.282118	test-merror:0.283349
# [28]	train-merror:0.281678	test-merror:0.283066
# [29]	train-merror:0.280913	test-merror:0.282500
# [30]	train-merror:0.280694	test-merror:0.282374
# [31]	train-merror:0.280346	test-merror:0.282103
# [32]	train-merror:0.280192	test-merror:0.281981
# [33]	train-merror:0.280025	test-merror:0.281850
# [34]	train-merror:0.279263	test-merror:0.281115
# [35]	train-merror:0.279035	test-merror:0.280969
# [36]	train-merror:0.278822	test-merror:0.280861
# [37]	train-merror:0.278489	test-merror:0.280559
# [38]	train-merror:0.278211	test-merror:0.280439
# [39]	train-merror:0.278040	test-merror:0.280367
# predicting, classification error=0.280367
# average AUC: 0.780841247616
# [('f329', 176, u'fat'),
#  ('f656', 174, u'peopl'),
#  ('f524', 155, u'like'),
#  ('f972', 140, u'white'),
#  ('f491', 116, u'just'),
#  ('f359', 113, u'fuck'),
#  ('f485', 99, u'jew'),
#  ('f259', 99, u'dont'),
#  ('f977', 95, u'women'),
#  ('f107', 91, u'black'),
#  ('f607', 90, u'nigger'),
#  ('f962', 77, u'weight'),
#  ('f618', 70, u'obes'),
#  ('f87', 65, u'becaus'),
#  ('f790', 64, u'say'),
#  ('f903', 61, u'think'),
#  ('f447', 61, u'im'),
#  ('f275', 55, u'eat'),
#  ('f365', 52, u'game'),
#  ('f567', 51, u'men')]

# %% [markdown]
# ### For max_features=500 (AUC .765, after 100) --> Did worse than max_features=1000 (.AUC .793, at 80 rounds)
# ### max_features=2000: (AUC .809, after 100)
# ### Max_features=4000: Auc = .825, after 100
# ### Max_features=8000: AUC = 0.835, after 100
# ### Max_features=3000: AUC = 0.825 after 310 rounds of boosting
# ### max_featres = 4000, max depth = 9: AUC =  .832 after ~210 rounds

# %%
tfidfv = TfidfVectorizer(decode_error = 'ignore', stop_words = 'english', max_features=3000, tokenizer=tokenize)

#Training vectors
tfidfv_fit_X_train = tfidfv.fit_transform(X_train)
pickle.dump(tfidfv_fit_X_train, open('../Data/tfidf3000_puncstrip_X_train.p', 'wb'))

#test vectora
tfidfv_fit_X_test = tfidfv.transform(X_test)
pickle.dump(tfidfv_fit_X_test, open('../Data/tfidf3000_puncstrip_X_test.p', 'wb'))

# %%
# tfidfv_X_train = pickle.load(open('tfidf1000_fittrans_X_train.p', 'rb'))
# tfidfv_X_test = pickle.load(open('tfidf1000_fittrans_X_train.p', 'rb'))

# %%
xg_train = xgb.DMatrix(tfidfv_fit_X_train, label=y_train)
xg_test = xgb.DMatrix(tfidfv_fit_X_test, label=y_test)

# %%
#max_features = 3000 
# Set up xboost parameters
param = {}
# scale weight of positive examples
param['eta'] = 0.90
param['max_depth'] = 6
param['silent'] = 1
# param['nthread'] = 4
param['num_class'] = 5
# output probabilities from softmax fn
param['objective'] = 'multi:softprob'

watchlist = [ (xg_train, 'train'), (xg_test, 'test') ]

num_round = 500



bst = xgb.train(param, xg_train, num_round, watchlist, early_stopping_rounds=5)
#bst = xgb.train(param, xg_train, num_round, watchlist );
# Note: this convention has been changed since xgboost-unity
# get prediction, this is in 1D array, need reshape to (ndata, nclass)
yprob = bst.predict( xg_test ).reshape( y_test.shape[0], 5 )
ylabel = np.argmax(yprob, axis=1)

print ('predicting, classification error=%f' % (sum( int(ylabel[i]) != y_test.iloc[i] for i in range(len(y_test))) / float(len(y_test)) ))

createmulticlassROC(classes, ylabel_bin, yprob)
print("average AUC: {0}").format(roc_auc_score(ylabel_bin, yprob))

top_features_words(bst.get_fscore(),tfidfv, n=20)
# Out:
# Will train until test error hasn't decreased in 5 rounds.
# [0]	train-merror:0.303219	test-merror:0.301460
# [1]	train-merror:0.296319	test-merror:0.295089
# [2]	train-merror:0.292174	test-merror:0.291311
# [3]	train-merror:0.288492	test-merror:0.288034
# [4]	train-merror:0.284977	test-merror:0.284830
# [5]	train-merror:0.281251	test-merror:0.281237
# [6]	train-merror:0.279078	test-merror:0.279343
# [7]	train-merror:0.277443	test-merror:0.278109
# [8]	train-merror:0.275888	test-merror:0.276846
# [9]	train-merror:0.274970	test-merror:0.276138
# [10]	train-merror:0.273305	test-merror:0.274636
# [11]	train-merror:0.272308	test-merror:0.273906
# [12]	train-merror:0.270719	test-merror:0.272704
# [13]	train-merror:0.269927	test-merror:0.271928
# [14]	train-merror:0.269217	test-merror:0.271341
# [15]	train-merror:0.268595	test-merror:0.270784
# [16]	train-merror:0.268009	test-merror:0.270315
# [17]	train-merror:0.267306	test-merror:0.269797
# [18]	train-merror:0.266790	test-merror:0.269457
# [19]	train-merror:0.266145	test-merror:0.268997
# [20]	train-merror:0.265254	test-merror:0.268312
# [21]	train-merror:0.264681	test-merror:0.267894
# [22]	train-merror:0.264284	test-merror:0.267472
# [23]	train-merror:0.263789	test-merror:0.266946
# [24]	train-merror:0.263190	test-merror:0.266508
# [25]	train-merror:0.262610	test-merror:0.266069
# [26]	train-merror:0.262013	test-merror:0.265699
# [27]	train-merror:0.261307	test-merror:0.265064
# [28]	train-merror:0.260892	test-merror:0.264787
# [29]	train-merror:0.260550	test-merror:0.264540
# [30]	train-merror:0.260080	test-merror:0.264210
# [31]	train-merror:0.259609	test-merror:0.263988
# [32]	train-merror:0.259145	test-merror:0.263689
# [33]	train-merror:0.258522	test-merror:0.263154
# [34]	train-merror:0.258008	test-merror:0.262806
# [35]	train-merror:0.257665	test-merror:0.262565
# [36]	train-merror:0.257278	test-merror:0.262313
# [37]	train-merror:0.256904	test-merror:0.262054
# [38]	train-merror:0.256330	test-merror:0.261697
# [39]	train-merror:0.255953	test-merror:0.261426
# [40]	train-merror:0.255649	test-merror:0.261217
# [41]	train-merror:0.254886	test-merror:0.260598
# [42]	train-merror:0.254565	test-merror:0.260408
# [43]	train-merror:0.254230	test-merror:0.260087
# [44]	train-merror:0.253887	test-merror:0.259884
# [45]	train-merror:0.253555	test-merror:0.259641
# [46]	train-merror:0.253321	test-merror:0.259458
# [47]	train-merror:0.252989	test-merror:0.259196
# [48]	train-merror:0.252647	test-merror:0.258923
# [49]	train-merror:0.252357	test-merror:0.258782
# [50]	train-merror:0.252042	test-merror:0.258570
# [51]	train-merror:0.251681	test-merror:0.258366
# [52]	train-merror:0.251299	test-merror:0.258188
# [53]	train-merror:0.251080	test-merror:0.258110
# [54]	train-merror:0.250730	test-merror:0.257800
# [55]	train-merror:0.250473	test-merror:0.257628
# [56]	train-merror:0.250320	test-merror:0.257527
# [57]	train-merror:0.250098	test-merror:0.257394
# [58]	train-merror:0.249854	test-merror:0.257229
# [59]	train-merror:0.249516	test-merror:0.256942
# [60]	train-merror:0.249318	test-merror:0.256822
# [61]	train-merror:0.249036	test-merror:0.256678
# [62]	train-merror:0.248868	test-merror:0.256570
# [63]	train-merror:0.248606	test-merror:0.256342
# [64]	train-merror:0.248306	test-merror:0.256114
# [65]	train-merror:0.248153	test-merror:0.256044
# [66]	train-merror:0.247804	test-merror:0.255763
# [67]	train-merror:0.247611	test-merror:0.255668
# [68]	train-merror:0.247398	test-merror:0.255495
# [69]	train-merror:0.246988	test-merror:0.255351
# [70]	train-merror:0.246852	test-merror:0.255237
# [71]	train-merror:0.246698	test-merror:0.255157
# [72]	train-merror:0.246498	test-merror:0.255064
# [73]	train-merror:0.246273	test-merror:0.254969
# [74]	train-merror:0.246015	test-merror:0.254813
# [75]	train-merror:0.245796	test-merror:0.254754
# [76]	train-merror:0.245610	test-merror:0.254631
# [77]	train-merror:0.245343	test-merror:0.254494
# [78]	train-merror:0.245115	test-merror:0.254304
# [79]	train-merror:0.244900	test-merror:0.254078
# [80]	train-merror:0.244637	test-merror:0.253898
# [81]	train-merror:0.244497	test-merror:0.253833
# [82]	train-merror:0.244304	test-merror:0.253679
# [83]	train-merror:0.244084	test-merror:0.253562
# [84]	train-merror:0.243885	test-merror:0.253408
# [85]	train-merror:0.243666	test-merror:0.253429
# [86]	train-merror:0.243470	test-merror:0.253300
# [87]	train-merror:0.243285	test-merror:0.253214
# [88]	train-merror:0.243123	test-merror:0.253108
# [89]	train-merror:0.242970	test-merror:0.253064
# [90]	train-merror:0.242778	test-merror:0.252998
# [91]	train-merror:0.242516	test-merror:0.252829
# [92]	train-merror:0.242366	test-merror:0.252679
# [93]	train-merror:0.242267	test-merror:0.252639
# [94]	train-merror:0.242104	test-merror:0.252576
# [95]	train-merror:0.241931	test-merror:0.252483
# [96]	train-merror:0.241711	test-merror:0.252392
# [97]	train-merror:0.241471	test-merror:0.252261
# [98]	train-merror:0.241328	test-merror:0.252168
# [99]	train-merror:0.241198	test-merror:0.252107
# [100]	train-merror:0.240964	test-merror:0.252020
# [101]	train-merror:0.240780	test-merror:0.251921
# [102]	train-merror:0.240647	test-merror:0.251860
# [103]	train-merror:0.240516	test-merror:0.251801
# [104]	train-merror:0.240342	test-merror:0.251687
# [105]	train-merror:0.240183	test-merror:0.251606
# [106]	train-merror:0.239967	test-merror:0.251516
# [107]	train-merror:0.239787	test-merror:0.251404
# [108]	train-merror:0.239626	test-merror:0.251332
# [109]	train-merror:0.239398	test-merror:0.251266
# [110]	train-merror:0.239301	test-merror:0.251218
# [111]	train-merror:0.239138	test-merror:0.251207
# [112]	train-merror:0.238978	test-merror:0.251178
# [113]	train-merror:0.238839	test-merror:0.251040
# [114]	train-merror:0.238600	test-merror:0.250821
# [115]	train-merror:0.238425	test-merror:0.250835
# [116]	train-merror:0.238308	test-merror:0.250768
# [117]	train-merror:0.238143	test-merror:0.250702
# [118]	train-merror:0.237939	test-merror:0.250523
# [119]	train-merror:0.237849	test-merror:0.250497
# [120]	train-merror:0.237752	test-merror:0.250455
# [121]	train-merror:0.237654	test-merror:0.250459
# [122]	train-merror:0.237492	test-merror:0.250301
# [123]	train-merror:0.237275	test-merror:0.250269
# [124]	train-merror:0.237118	test-merror:0.250134
# [125]	train-merror:0.236979	test-merror:0.250041
# [126]	train-merror:0.236879	test-merror:0.249993
# [127]	train-merror:0.236771	test-merror:0.249971
# [128]	train-merror:0.236660	test-merror:0.249889
# [129]	train-merror:0.236554	test-merror:0.249830
# [130]	train-merror:0.236321	test-merror:0.249769
# [131]	train-merror:0.236202	test-merror:0.249771
# [132]	train-merror:0.236066	test-merror:0.249688
# [133]	train-merror:0.235938	test-merror:0.249655
# [134]	train-merror:0.235878	test-merror:0.249623
# [135]	train-merror:0.235797	test-merror:0.249615
# [136]	train-merror:0.235630	test-merror:0.249536
# [137]	train-merror:0.235508	test-merror:0.249498
# [138]	train-merror:0.235440	test-merror:0.249465
# [139]	train-merror:0.235274	test-merror:0.249439
# [140]	train-merror:0.235167	test-merror:0.249448
# [141]	train-merror:0.235096	test-merror:0.249418
# [142]	train-merror:0.235018	test-merror:0.249450
# [143]	train-merror:0.234899	test-merror:0.249374
# [144]	train-merror:0.234809	test-merror:0.249302
# [145]	train-merror:0.234663	test-merror:0.249274
# [146]	train-merror:0.234571	test-merror:0.249243
# [147]	train-merror:0.234490	test-merror:0.249230
# [148]	train-merror:0.234396	test-merror:0.249184
# [149]	train-merror:0.234155	test-merror:0.249099
# [150]	train-merror:0.234074	test-merror:0.249103
# [151]	train-merror:0.233752	test-merror:0.248989
# [152]	train-merror:0.233546	test-merror:0.248829
# [153]	train-merror:0.233463	test-merror:0.248791
# [154]	train-merror:0.233384	test-merror:0.248761
# [155]	train-merror:0.233236	test-merror:0.248740
# [156]	train-merror:0.233101	test-merror:0.248702
# [157]	train-merror:0.233029	test-merror:0.248700
# [158]	train-merror:0.232942	test-merror:0.248700
# [159]	train-merror:0.232839	test-merror:0.248715
# [160]	train-merror:0.232746	test-merror:0.248672
# [161]	train-merror:0.232632	test-merror:0.248653
# [162]	train-merror:0.232517	test-merror:0.248548
# [163]	train-merror:0.232388	test-merror:0.248503
# [164]	train-merror:0.232278	test-merror:0.248482
# [165]	train-merror:0.232176	test-merror:0.248453
# [166]	train-merror:0.232110	test-merror:0.248444
# [167]	train-merror:0.232010	test-merror:0.248451
# [168]	train-merror:0.231932	test-merror:0.248463
# [169]	train-merror:0.231824	test-merror:0.248430
# [170]	train-merror:0.231698	test-merror:0.248411
# [171]	train-merror:0.231541	test-merror:0.248368
# [172]	train-merror:0.231474	test-merror:0.248379
# [173]	train-merror:0.231413	test-merror:0.248322
# [174]	train-merror:0.231351	test-merror:0.248320
# [175]	train-merror:0.231235	test-merror:0.248231
# [176]	train-merror:0.231132	test-merror:0.248195
# [177]	train-merror:0.231069	test-merror:0.248163
# [178]	train-merror:0.230936	test-merror:0.248102
# [179]	train-merror:0.230811	test-merror:0.248108
# [180]	train-merror:0.230720	test-merror:0.248066
# [181]	train-merror:0.230633	test-merror:0.247971
# [182]	train-merror:0.230543	test-merror:0.247954
# [183]	train-merror:0.230480	test-merror:0.247918
# [184]	train-merror:0.230393	test-merror:0.247828
# [185]	train-merror:0.230301	test-merror:0.247781
# [186]	train-merror:0.230166	test-merror:0.247766
# [187]	train-merror:0.230076	test-merror:0.247735
# [188]	train-merror:0.229978	test-merror:0.247625
# [189]	train-merror:0.229939	test-merror:0.247593
# [190]	train-merror:0.229776	test-merror:0.247580
# [191]	train-merror:0.229697	test-merror:0.247583
# [192]	train-merror:0.229592	test-merror:0.247589
# [193]	train-merror:0.229498	test-merror:0.247568
# [194]	train-merror:0.229417	test-merror:0.247564
# [195]	train-merror:0.229296	test-merror:0.247549
# [196]	train-merror:0.229222	test-merror:0.247544
# [197]	train-merror:0.229110	test-merror:0.247549
# [198]	train-merror:0.229050	test-merror:0.247544
# [199]	train-merror:0.228976	test-merror:0.247485
# [200]	train-merror:0.228810	test-merror:0.247487
# [201]	train-merror:0.228730	test-merror:0.247498
# [202]	train-merror:0.228637	test-merror:0.247519
# [203]	train-merror:0.228513	test-merror:0.247441
# [204]	train-merror:0.228438	test-merror:0.247382
# [205]	train-merror:0.228346	test-merror:0.247369
# [206]	train-merror:0.228251	test-merror:0.247365
# [207]	train-merror:0.228151	test-merror:0.247344
# [208]	train-merror:0.228079	test-merror:0.247329
# [209]	train-merror:0.227933	test-merror:0.247306
# [210]	train-merror:0.227830	test-merror:0.247291
# [211]	train-merror:0.227726	test-merror:0.247283
# [212]	train-merror:0.227686	test-merror:0.247249
# [213]	train-merror:0.227558	test-merror:0.247200
# [214]	train-merror:0.227472	test-merror:0.247228
# [215]	train-merror:0.227374	test-merror:0.247185
# [216]	train-merror:0.227178	test-merror:0.247097
# [217]	train-merror:0.227097	test-merror:0.247048
# [218]	train-merror:0.227028	test-merror:0.247063
# [219]	train-merror:0.226894	test-merror:0.246993
# [220]	train-merror:0.226792	test-merror:0.246989
# [221]	train-merror:0.226599	test-merror:0.246926
# [222]	train-merror:0.226453	test-merror:0.246826
# [223]	train-merror:0.226354	test-merror:0.246807
# [224]	train-merror:0.226304	test-merror:0.246799
# [225]	train-merror:0.226246	test-merror:0.246780
# [226]	train-merror:0.226169	test-merror:0.246797
# [227]	train-merror:0.226059	test-merror:0.246752
# [228]	train-merror:0.225988	test-merror:0.246752
# [229]	train-merror:0.225875	test-merror:0.246723
# [230]	train-merror:0.225798	test-merror:0.246693
# [231]	train-merror:0.225722	test-merror:0.246712
# [232]	train-merror:0.225679	test-merror:0.246672
# [233]	train-merror:0.225614	test-merror:0.246689
# [234]	train-merror:0.225526	test-merror:0.246662
# [235]	train-merror:0.225414	test-merror:0.246645
# [236]	train-merror:0.225336	test-merror:0.246609
# [237]	train-merror:0.225257	test-merror:0.246596
# [238]	train-merror:0.225213	test-merror:0.246583
# [239]	train-merror:0.225107	test-merror:0.246607
# [240]	train-merror:0.224994	test-merror:0.246564
# [241]	train-merror:0.224935	test-merror:0.246554
# [242]	train-merror:0.224846	test-merror:0.246581
# [243]	train-merror:0.224779	test-merror:0.246613
# [244]	train-merror:0.224692	test-merror:0.246579
# [245]	train-merror:0.224634	test-merror:0.246569
# [246]	train-merror:0.224569	test-merror:0.246514
# [247]	train-merror:0.224522	test-merror:0.246535
# [248]	train-merror:0.224434	test-merror:0.246501
# [249]	train-merror:0.224330	test-merror:0.246524
# [250]	train-merror:0.224292	test-merror:0.246531
# [251]	train-merror:0.224215	test-merror:0.246509
# [252]	train-merror:0.224124	test-merror:0.246471
# [253]	train-merror:0.224068	test-merror:0.246461
# [254]	train-merror:0.223970	test-merror:0.246446
# [255]	train-merror:0.223859	test-merror:0.246444
# [256]	train-merror:0.223791	test-merror:0.246444
# [257]	train-merror:0.223696	test-merror:0.246417
# [258]	train-merror:0.223636	test-merror:0.246421
# [259]	train-merror:0.223589	test-merror:0.246423
# [260]	train-merror:0.223519	test-merror:0.246421
# [261]	train-merror:0.223468	test-merror:0.246419
# [262]	train-merror:0.223401	test-merror:0.246412
# [263]	train-merror:0.223300	test-merror:0.246391
# [264]	train-merror:0.223207	test-merror:0.246417
# [265]	train-merror:0.223110	test-merror:0.246385
# [266]	train-merror:0.223035	test-merror:0.246391
# [267]	train-merror:0.222979	test-merror:0.246364
# [268]	train-merror:0.222945	test-merror:0.246357
# [269]	train-merror:0.222864	test-merror:0.246353
# [270]	train-merror:0.222795	test-merror:0.246330
# [271]	train-merror:0.222674	test-merror:0.246338
# [272]	train-merror:0.222607	test-merror:0.246328
# [273]	train-merror:0.222585	test-merror:0.246296
# [274]	train-merror:0.222508	test-merror:0.246283
# [275]	train-merror:0.222413	test-merror:0.246260
# [276]	train-merror:0.222336	test-merror:0.246140
# [277]	train-merror:0.222286	test-merror:0.246125
# [278]	train-merror:0.222220	test-merror:0.246127
# [279]	train-merror:0.222176	test-merror:0.246123
# [280]	train-merror:0.222104	test-merror:0.246112
# [281]	train-merror:0.222045	test-merror:0.246121
# [282]	train-merror:0.221989	test-merror:0.246076
# [283]	train-merror:0.221916	test-merror:0.246068
# [284]	train-merror:0.221846	test-merror:0.246053
# [285]	train-merror:0.221763	test-merror:0.246028
# [286]	train-merror:0.221697	test-merror:0.246028
# [287]	train-merror:0.221624	test-merror:0.246000
# [288]	train-merror:0.221535	test-merror:0.246005
# [289]	train-merror:0.221412	test-merror:0.246013
# [290]	train-merror:0.221363	test-merror:0.245984
# [291]	train-merror:0.221271	test-merror:0.245973
# [292]	train-merror:0.221184	test-merror:0.245967
# [293]	train-merror:0.221107	test-merror:0.245956
# [294]	train-merror:0.221061	test-merror:0.245946
# [295]	train-merror:0.220988	test-merror:0.245939
# [296]	train-merror:0.220922	test-merror:0.245943
# [297]	train-merror:0.220894	test-merror:0.245926
# [298]	train-merror:0.220836	test-merror:0.245874
# [299]	train-merror:0.220738	test-merror:0.245853
# [300]	train-merror:0.220714	test-merror:0.245867
# [301]	train-merror:0.220648	test-merror:0.245869
# [302]	train-merror:0.220608	test-merror:0.245846
# [303]	train-merror:0.220511	test-merror:0.245834
# [304]	train-merror:0.220483	test-merror:0.245825
# [305]	train-merror:0.220418	test-merror:0.245834
# [306]	train-merror:0.220341	test-merror:0.245859
# [307]	train-merror:0.220323	test-merror:0.245867
# [308]	train-merror:0.220290	test-merror:0.245882
# predicting, classification error=0.245876
# [309]	train-merror:0.220235	test-merror:0.245876
# Stopping. Best iteration:
# [304]	train-merror:0.220483	test-merror:0.245825
# average AUC: 0.825065382025
# [('f1601', 824, u'like'),
#  ('f1948', 745, u'peopl'),
#  ('f1515', 724, u'just'),
#  ('f838', 488, u'dont'),
#  ('f1039', 428, u'fat'),
#  ('f1376', 369, u'im'),
#  ('f293', 353, u'becaus'),
#  ('f2686', 325, u'think'),
#  ('f1141', 316, u'fuck'),
#  ('f1647', 295, u'make'),
#  ('f2320', 262, u'say'),
#  ('f2922', 236, u'white'),
#  ('f1536', 233, u'know'),
#  ('f2685', 216, u'thing'),
#  ('f1201', 212, u'good'),
#  ('f2943', 211, u'women'),
#  ('f1870', 208, u'onli'),
#  ('f1622', 207, u'look'),
#  ('f2878', 202, u'want'),
#  ('f2817', 202, u'use')]

# %%
bst.save_model('XGBoost3000strip_310rounds.model')

# %%
# tfidfv = TfidfVectorizer(decode_error = 'ignore', stop_words = 'english', max_features=4000, tokenizer=tokenize)

# #Training vectors
# tfidfv_fit_X_train = tfidfv.fit_transform(X_train)
# pickle.dump(tfidfv_fit_X_train, open('../Data/tfidf4000_puncstrip_X_train.p', 'wb'))

# #test vectora
# tfidfv_fit_X_test = tfidfv.transform(X_test)
# pickle.dump(tfidfv_fit_X_test, open('../Data/tfidf4000_puncstrip_X_test.p', 'wb'))

tfidfv_fit_X_train = pickle.load(open('../Data/tfidf4000_puncstrip_X_train.p', 'rb'))
tfidfv_fit_X_test = pickle.load(open('../Data/tfidf4000_puncstrip_X_test.p', 'rb'))

xg_train = xgb.DMatrix(tfidfv_fit_X_train, label=y_train)
xg_test = xgb.DMatrix(tfidfv_fit_X_test, label=y_test)

# %%
# max_features = 4000
# Set up xboost parameters
param = {}
# scale weight of positive examples
param['eta'] = 0.90
param['max_depth'] = 9  #increased from 6 previously
param['silent'] = 1
# param['nthread'] = 4
param['num_class'] = 5
# output probabilities from softmax fn
param['objective'] = 'multi:softprob'

watchlist = [ (xg_train, 'train'), (xg_test, 'test') ]

num_round = 400


bst = xgb.train(param, xg_train, num_round, watchlist, early_stopping_rounds=5)
#bst = xgb.train(param, xg_train, num_round, watchlist );
# Note: this convention has been changed since xgboost-unity
# get prediction, this is in 1D array, need reshape to (ndata, nclass)
yprob = bst.predict( xg_test ).reshape( y_test.shape[0], 5 )
ylabel = np.argmax(yprob, axis=1)

print ('predicting, classification error=%f' % (sum( int(ylabel[i]) != y_test.iloc[i] for i in range(len(y_test))) / float(len(y_test)) ))

createmulticlassROC(classes, ylabel_bin, yprob)
print("average AUC: {0}").format(roc_auc_score(ylabel_bin, yprob))

top_features_words(bst.get_fscore(),tfidfv, n=20)
# Out:
# Will train until test error hasn't decreased in 5 rounds.
# [0]	train-merror:0.297314	test-merror:0.296638
# [1]	train-merror:0.288450	test-merror:0.288396
# [2]	train-merror:0.281753	test-merror:0.282712
# [3]	train-merror:0.276844	test-merror:0.278403
# [4]	train-merror:0.272274	test-merror:0.274668
# [5]	train-merror:0.269763	test-merror:0.272740
# [6]	train-merror:0.267127	test-merror:0.270553
# [7]	train-merror:0.265238	test-merror:0.269140
# [8]	train-merror:0.263623	test-merror:0.267774
# [9]	train-merror:0.262115	test-merror:0.266798
# [10]	train-merror:0.260705	test-merror:0.265653
# [11]	train-merror:0.259576	test-merror:0.264823
# [12]	train-merror:0.258277	test-merror:0.263963
# [13]	train-merror:0.257379	test-merror:0.263279
# [14]	train-merror:0.256249	test-merror:0.262485
# [15]	train-merror:0.255264	test-merror:0.261741
# [16]	train-merror:0.254400	test-merror:0.261367
# [17]	train-merror:0.253532	test-merror:0.260774
# [18]	train-merror:0.252741	test-merror:0.260150
# [19]	train-merror:0.251847	test-merror:0.259523
# [20]	train-merror:0.251289	test-merror:0.259187
# [21]	train-merror:0.250470	test-merror:0.258712
# [22]	train-merror:0.249768	test-merror:0.258304
# [23]	train-merror:0.249078	test-merror:0.257850
# [24]	train-merror:0.248507	test-merror:0.257574
# [25]	train-merror:0.247596	test-merror:0.257113
# [26]	train-merror:0.247147	test-merror:0.256752
# [27]	train-merror:0.246646	test-merror:0.256467
# [28]	train-merror:0.245914	test-merror:0.255945
# [29]	train-merror:0.245380	test-merror:0.255641
# [30]	train-merror:0.244585	test-merror:0.254952
# [31]	train-merror:0.244006	test-merror:0.254475
# [32]	train-merror:0.243595	test-merror:0.254192
# [33]	train-merror:0.243219	test-merror:0.254044
# [34]	train-merror:0.242720	test-merror:0.253809
# [35]	train-merror:0.242262	test-merror:0.253564
# [36]	train-merror:0.241790	test-merror:0.253294
# [37]	train-merror:0.241036	test-merror:0.252865
# [38]	train-merror:0.240414	test-merror:0.252508
# [39]	train-merror:0.240027	test-merror:0.252280
# [40]	train-merror:0.239745	test-merror:0.252238
# [41]	train-merror:0.239272	test-merror:0.251989
# [42]	train-merror:0.238810	test-merror:0.251585
# [43]	train-merror:0.238432	test-merror:0.251382
# [44]	train-merror:0.237938	test-merror:0.251190
# [45]	train-merror:0.237626	test-merror:0.251055
# [46]	train-merror:0.237188	test-merror:0.250833
# [47]	train-merror:0.236878	test-merror:0.250692
# [48]	train-merror:0.236544	test-merror:0.250538
# [49]	train-merror:0.236206	test-merror:0.250373
# [50]	train-merror:0.235933	test-merror:0.250223
# [51]	train-merror:0.235512	test-merror:0.250092
# [52]	train-merror:0.234944	test-merror:0.249760
# [53]	train-merror:0.234513	test-merror:0.249490
# [54]	train-merror:0.234159	test-merror:0.249336
# [55]	train-merror:0.233872	test-merror:0.249169
# [56]	train-merror:0.233388	test-merror:0.248922
# [57]	train-merror:0.233105	test-merror:0.248778
# [58]	train-merror:0.232677	test-merror:0.248634
# [59]	train-merror:0.232402	test-merror:0.248506
# [60]	train-merror:0.232058	test-merror:0.248360
# [61]	train-merror:0.231890	test-merror:0.248345
# [62]	train-merror:0.231629	test-merror:0.248208
# [63]	train-merror:0.231437	test-merror:0.248157
# [64]	train-merror:0.231003	test-merror:0.247973
# [65]	train-merror:0.230615	test-merror:0.247838
# [66]	train-merror:0.230304	test-merror:0.247686
# [67]	train-merror:0.230017	test-merror:0.247616
# [68]	train-merror:0.229713	test-merror:0.247511
# [69]	train-merror:0.229508	test-merror:0.247466
# [70]	train-merror:0.229194	test-merror:0.247323
# [71]	train-merror:0.228982	test-merror:0.247196
# [72]	train-merror:0.228742	test-merror:0.247078
# [73]	train-merror:0.228274	test-merror:0.246782
# [74]	train-merror:0.228061	test-merror:0.246714
# [75]	train-merror:0.227824	test-merror:0.246628
# [76]	train-merror:0.227498	test-merror:0.246486
# [77]	train-merror:0.227257	test-merror:0.246404
# [78]	train-merror:0.227022	test-merror:0.246290
# [79]	train-merror:0.226708	test-merror:0.246142
# [80]	train-merror:0.226471	test-merror:0.246070
# [81]	train-merror:0.226251	test-merror:0.245941
# [82]	train-merror:0.225927	test-merror:0.245810
# [83]	train-merror:0.225750	test-merror:0.245745
# [84]	train-merror:0.225537	test-merror:0.245662
# [85]	train-merror:0.225319	test-merror:0.245582
# [86]	train-merror:0.225155	test-merror:0.245521
# [87]	train-merror:0.224800	test-merror:0.245373
# [88]	train-merror:0.224579	test-merror:0.245280
# [89]	train-merror:0.224387	test-merror:0.245204
# [90]	train-merror:0.224169	test-merror:0.245206
# [91]	train-merror:0.223894	test-merror:0.245170
# [92]	train-merror:0.223696	test-merror:0.245115
# [93]	train-merror:0.223558	test-merror:0.245115
# [94]	train-merror:0.223395	test-merror:0.245046
# [95]	train-merror:0.223124	test-merror:0.244959
# [96]	train-merror:0.222950	test-merror:0.244919
# [97]	train-merror:0.222737	test-merror:0.244860
# [98]	train-merror:0.222471	test-merror:0.244830
# [99]	train-merror:0.222222	test-merror:0.244788
# [100]	train-merror:0.222064	test-merror:0.244763
# [101]	train-merror:0.221832	test-merror:0.244663
# [102]	train-merror:0.221565	test-merror:0.244632
# [103]	train-merror:0.221337	test-merror:0.244551
# [104]	train-merror:0.221159	test-merror:0.244492
# [105]	train-merror:0.220997	test-merror:0.244456
# [106]	train-merror:0.220760	test-merror:0.244332
# [107]	train-merror:0.220562	test-merror:0.244277
# [108]	train-merror:0.220339	test-merror:0.244192
# [109]	train-merror:0.220133	test-merror:0.244106
# [110]	train-merror:0.219978	test-merror:0.244087
# [111]	train-merror:0.219847	test-merror:0.244121
# [112]	train-merror:0.219662	test-merror:0.244021
# [113]	train-merror:0.219392	test-merror:0.243918
# [114]	train-merror:0.219185	test-merror:0.243873
# [115]	train-merror:0.218619	test-merror:0.243704
# [116]	train-merror:0.218419	test-merror:0.243713
# [117]	train-merror:0.218214	test-merror:0.243597
# [118]	train-merror:0.218005	test-merror:0.243531
# [119]	train-merror:0.217843	test-merror:0.243493
# [120]	train-merror:0.217628	test-merror:0.243445
# [121]	train-merror:0.217469	test-merror:0.243398
# [122]	train-merror:0.217304	test-merror:0.243415
# [123]	train-merror:0.217096	test-merror:0.243345
# [124]	train-merror:0.216958	test-merror:0.243314
# [125]	train-merror:0.216807	test-merror:0.243324
# [126]	train-merror:0.216681	test-merror:0.243305
# [127]	train-merror:0.216554	test-merror:0.243229
# [128]	train-merror:0.216387	test-merror:0.243193
# [129]	train-merror:0.216203	test-merror:0.243121
# [130]	train-merror:0.216015	test-merror:0.243081
# [131]	train-merror:0.215881	test-merror:0.243054
# [132]	train-merror:0.215669	test-merror:0.242997
# [133]	train-merror:0.215457	test-merror:0.242908
# [134]	train-merror:0.215265	test-merror:0.242855
# [135]	train-merror:0.214949	test-merror:0.242800
# [136]	train-merror:0.214819	test-merror:0.242760
# [137]	train-merror:0.214649	test-merror:0.242629
# [138]	train-merror:0.214461	test-merror:0.242541
# [139]	train-merror:0.214351	test-merror:0.242471
# [140]	train-merror:0.214190	test-merror:0.242414
# [141]	train-merror:0.214034	test-merror:0.242393
# [142]	train-merror:0.213826	test-merror:0.242336
# [143]	train-merror:0.213667	test-merror:0.242289
# [144]	train-merror:0.213538	test-merror:0.242258
# [145]	train-merror:0.213351	test-merror:0.242156
# [146]	train-merror:0.213155	test-merror:0.242055
# [147]	train-merror:0.212988	test-merror:0.242012
# [148]	train-merror:0.212782	test-merror:0.241983
# [149]	train-merror:0.212656	test-merror:0.241968
# [150]	train-merror:0.212440	test-merror:0.241945
# [151]	train-merror:0.212314	test-merror:0.241905
# [152]	train-merror:0.212181	test-merror:0.241835
# [153]	train-merror:0.211996	test-merror:0.241784
# [154]	train-merror:0.211866	test-merror:0.241791
# [155]	train-merror:0.211738	test-merror:0.241797
# [156]	train-merror:0.211576	test-merror:0.241770
# [157]	train-merror:0.211404	test-merror:0.241763
# [158]	train-merror:0.211221	test-merror:0.241656
# [159]	train-merror:0.211115	test-merror:0.241634
# [160]	train-merror:0.210954	test-merror:0.241613
# [161]	train-merror:0.210813	test-merror:0.241590
# [162]	train-merror:0.210612	test-merror:0.241529
# [163]	train-merror:0.210496	test-merror:0.241501
# [164]	train-merror:0.210372	test-merror:0.241468
# [165]	train-merror:0.210253	test-merror:0.241404
# [166]	train-merror:0.210113	test-merror:0.241334
# [167]	train-merror:0.210031	test-merror:0.241315
# [168]	train-merror:0.209896	test-merror:0.241309
# [169]	train-merror:0.209767	test-merror:0.241239
# [170]	train-merror:0.209632	test-merror:0.241237
# [171]	train-merror:0.209533	test-merror:0.241231
# [172]	train-merror:0.209384	test-merror:0.241225
# [173]	train-merror:0.209217	test-merror:0.241125
# [174]	train-merror:0.209079	test-merror:0.241089
# [175]	train-merror:0.208953	test-merror:0.241041
# [176]	train-merror:0.208807	test-merror:0.241035
# [177]	train-merror:0.208670	test-merror:0.241001
# [178]	train-merror:0.208532	test-merror:0.241022
# [179]	train-merror:0.208427	test-merror:0.241039
# [180]	train-merror:0.208280	test-merror:0.241015
# [181]	train-merror:0.208156	test-merror:0.241007
# [182]	train-merror:0.208001	test-merror:0.240956
# [183]	train-merror:0.207901	test-merror:0.240990
# [184]	train-merror:0.207748	test-merror:0.240965
# [185]	train-merror:0.207635	test-merror:0.240912
# [186]	train-merror:0.207466	test-merror:0.240868
# [187]	train-merror:0.207351	test-merror:0.240853
# [188]	train-merror:0.207190	test-merror:0.240844
# [189]	train-merror:0.207067	test-merror:0.240800
# [190]	train-merror:0.206950	test-merror:0.240817
# [191]	train-merror:0.206846	test-merror:0.240764
# [192]	train-merror:0.206665	test-merror:0.240728
# [193]	train-merror:0.206521	test-merror:0.240707
# [194]	train-merror:0.206421	test-merror:0.240686
# [195]	train-merror:0.206351	test-merror:0.240669
# [196]	train-merror:0.206286	test-merror:0.240627
# [197]	train-merror:0.206190	test-merror:0.240601
# [198]	train-merror:0.206060	test-merror:0.240597
# [199]	train-merror:0.205963	test-merror:0.240591
# [200]	train-merror:0.205812	test-merror:0.240549
# [201]	train-merror:0.205604	test-merror:0.240551
# [202]	train-merror:0.205497	test-merror:0.240576
# [203]	train-merror:0.205401	test-merror:0.240566
# [204]	train-merror:0.205355	test-merror:0.240551
# [205]	train-merror:0.205207	test-merror:0.240492
# [206]	train-merror:0.205063	test-merror:0.240481
# [207]	train-merror:0.204941	test-merror:0.240471
# [208]	train-merror:0.204842	test-merror:0.240471
# [209]	train-merror:0.204687	test-merror:0.240462
# [210]	train-merror:0.204597	test-merror:0.240403
# [211]	train-merror:0.204505	test-merror:0.240375
# [212]	train-merror:0.204365	test-merror:0.240390
# [213]	train-merror:0.204253	test-merror:0.240392
# [214]	train-merror:0.204106	test-merror:0.240411
# [215]	train-merror:0.203965	test-merror:0.240386
# [216]	train-merror:0.203829	test-merror:0.240392
# predicting, classification error=0.240392
# Stopping. Best iteration:
# [211]	train-merror:0.204505	test-merror:0.240375
# average AUC: 0.832021299915
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-8cc22e461e63> in <module>()
#      28 print("average AUC: {0}").format(roc_auc_score(ylabel_bin, yprob))
#      29
# ---> 30 top_features_words(bst.get_fscore(),tfidfv, n=20)
#
# <ipython-input-33-53569e713a39> in top_features_words(d, vect, n)
#      25         fname = featureslist[i][0]
#      26         fnum=int(filter(lambda x: x.isdigit(),fname))
# ---> 27         topfeatures.append((featureslist[i][0],featureslist[i][1],dictb[fnum]))
#      28
#      29     return topfeatures
#
# KeyError: 3599

# %%
bst.save_model('XGBoost4000strip_400maxrounds.model')

# %%
ylabel.size
# Out:
# 473426

# %%
y_test.shape
# Out:
# (473426,)

# %%
tfidfv = TfidfVectorizer(decode_error = 'ignore', stop_words = 'english', max_features=8000, tokenizer=tokenize)

#Training vectors
tfidfv_fit_X_train = tfidfv.fit_transform(X_train)
pickle.dump(tfidfv_fit_X_train, open('../Data/tfidf8000_puncstrip_X_train.p', 'wb'))

#test vectora
tfidfv_fit_X_test = tfidfv.transform(X_test)
pickle.dump(tfidfv_fit_X_test, open('../Data/tfidf8000_puncstrip_X_test.p', 'wb'))


xg_train = xgb.DMatrix(tfidfv_fit_X_train, label=y_train)
xg_test = xgb.DMatrix(tfidfv_fit_X_test, label=y_test)

# %%
# 8000 max_features
# Set up xboost parameters
param = {}
# scale weight of positive examples
param['eta'] = 0.90
param['max_depth'] = 6
param['silent'] = 1
# param['nthread'] = 4
param['num_class'] = 5
# output probabilities from softmax fn
param['objective'] = 'multi:softprob'

watchlist = [ (xg_train, 'train'), (xg_test, 'test') ]

num_round = 100


bst = xgb.train(param, xg_train, num_round, watchlist, early_stopping_rounds=5)
#bst = xgb.train(param, xg_train, num_round, watchlist );
# Note: this convention has been changed since xgboost-unity
# get prediction, this is in 1D array, need reshape to (ndata, nclass)
yprob = bst.predict( xg_test ).reshape( y_test.shape[0], 5 )
ylabel = np.argmax(yprob, axis=1)

print ('predicting, classification error=%f' % (sum( int(ylabel[i]) != y_test.iloc[i] for i in range(len(y_test))) / float(len(y_test)) ))

createmulticlassROC(classes, ylabel_bin, yprob)
print("average AUC: {0}").format(roc_auc_score(ylabel_bin, yprob))

top_features_words(bst.get_fscore(),tfidfv, n=20)
# Out:
# Will train until test error hasn't decreased in 5 rounds.
# [0]	train-merror:0.303529	test-merror:0.301872
# [1]	train-merror:0.296335	test-merror:0.295034
# [2]	train-merror:0.290443	test-merror:0.289479
# [3]	train-merror:0.286849	test-merror:0.286127
# [4]	train-merror:0.283100	test-merror:0.282824
# [5]	train-merror:0.279008	test-merror:0.278857
# [6]	train-merror:0.276362	test-merror:0.276417
# [7]	train-merror:0.274016	test-merror:0.274260
# [8]	train-merror:0.272183	test-merror:0.272522
# [9]	train-merror:0.270588	test-merror:0.271086
# [10]	train-merror:0.268912	test-merror:0.269417
# [11]	train-merror:0.267375	test-merror:0.268376
# [12]	train-merror:0.266196	test-merror:0.267410
# [13]	train-merror:0.265075	test-merror:0.266549
# [14]	train-merror:0.263135	test-merror:0.264730
# [15]	train-merror:0.262189	test-merror:0.263908
# [16]	train-merror:0.261320	test-merror:0.263245
# [17]	train-merror:0.260608	test-merror:0.262622
# [18]	train-merror:0.259992	test-merror:0.262246
# [19]	train-merror:0.259176	test-merror:0.261534
# [20]	train-merror:0.258624	test-merror:0.261177
# [21]	train-merror:0.257766	test-merror:0.260545
# [22]	train-merror:0.257368	test-merror:0.260205
# [23]	train-merror:0.256732	test-merror:0.259736
# [24]	train-merror:0.256090	test-merror:0.259115
# [25]	train-merror:0.255568	test-merror:0.258680
# [26]	train-merror:0.254844	test-merror:0.258110
# [27]	train-merror:0.254281	test-merror:0.257726
# [28]	train-merror:0.253506	test-merror:0.257130
# [29]	train-merror:0.252943	test-merror:0.256695
# [30]	train-merror:0.252415	test-merror:0.256342
# [31]	train-merror:0.251868	test-merror:0.255863
# [32]	train-merror:0.251383	test-merror:0.255472
# [33]	train-merror:0.250855	test-merror:0.255134
# [34]	train-merror:0.250525	test-merror:0.254906
# [35]	train-merror:0.250062	test-merror:0.254568
# [36]	train-merror:0.249668	test-merror:0.254261
# [37]	train-merror:0.249298	test-merror:0.253921
# [38]	train-merror:0.248702	test-merror:0.253463
# [39]	train-merror:0.248286	test-merror:0.253125
# [40]	train-merror:0.247953	test-merror:0.252872
# [41]	train-merror:0.247358	test-merror:0.252472
# [42]	train-merror:0.246970	test-merror:0.252175
# [43]	train-merror:0.246593	test-merror:0.251904
# [44]	train-merror:0.246176	test-merror:0.251630
# [45]	train-merror:0.245804	test-merror:0.251323
# [46]	train-merror:0.245400	test-merror:0.251097
# [47]	train-merror:0.244803	test-merror:0.250582
# [48]	train-merror:0.244398	test-merror:0.250303
# [49]	train-merror:0.244094	test-merror:0.250117
# [50]	train-merror:0.243678	test-merror:0.249819
# [51]	train-merror:0.243303	test-merror:0.249498
# [52]	train-merror:0.242868	test-merror:0.249146
# [53]	train-merror:0.242547	test-merror:0.248926
# [54]	train-merror:0.242316	test-merror:0.248723
# [55]	train-merror:0.241847	test-merror:0.248370
# [56]	train-merror:0.241465	test-merror:0.248125
# [57]	train-merror:0.241167	test-merror:0.247927
# [58]	train-merror:0.240910	test-merror:0.247792
# [59]	train-merror:0.240623	test-merror:0.247542
# [60]	train-merror:0.240265	test-merror:0.247312
# [61]	train-merror:0.239976	test-merror:0.247095
# [62]	train-merror:0.239598	test-merror:0.246862
# [63]	train-merror:0.239285	test-merror:0.246708
# [64]	train-merror:0.238961	test-merror:0.246499
# [65]	train-merror:0.238726	test-merror:0.246414
# [66]	train-merror:0.238415	test-merror:0.246129
# [67]	train-merror:0.238104	test-merror:0.245924
# [68]	train-merror:0.237891	test-merror:0.245806
# [69]	train-merror:0.237754	test-merror:0.245652
# [70]	train-merror:0.237390	test-merror:0.245422
# [71]	train-merror:0.237172	test-merror:0.245322
# [72]	train-merror:0.237028	test-merror:0.245170
# [73]	train-merror:0.236717	test-merror:0.245063
# [74]	train-merror:0.236409	test-merror:0.244805
# [75]	train-merror:0.236165	test-merror:0.244549
# [76]	train-merror:0.235945	test-merror:0.244416
# [77]	train-merror:0.235617	test-merror:0.244287
# [78]	train-merror:0.235396	test-merror:0.244121
# [79]	train-merror:0.235206	test-merror:0.244028
# [80]	train-merror:0.234925	test-merror:0.243916
# [81]	train-merror:0.234713	test-merror:0.243797
# [82]	train-merror:0.234511	test-merror:0.243675
# [83]	train-merror:0.234322	test-merror:0.243561
# [84]	train-merror:0.234039	test-merror:0.243407
# [85]	train-merror:0.233886	test-merror:0.243242
# [86]	train-merror:0.233671	test-merror:0.243107
# [87]	train-merror:0.233437	test-merror:0.242948
# [88]	train-merror:0.233177	test-merror:0.242752
# [89]	train-merror:0.233033	test-merror:0.242665
# [90]	train-merror:0.232875	test-merror:0.242600
# [91]	train-merror:0.232654	test-merror:0.242450
# [92]	train-merror:0.232519	test-merror:0.242397
# [93]	train-merror:0.232257	test-merror:0.242298
# [94]	train-merror:0.232043	test-merror:0.242154
# [95]	train-merror:0.231867	test-merror:0.242027
# [96]	train-merror:0.231714	test-merror:0.241903
# [97]	train-merror:0.231432	test-merror:0.241755
# [98]	train-merror:0.231251	test-merror:0.241670
# predicting, classification error=0.241662
# [99]	train-merror:0.231047	test-merror:0.241662
# average AUC: 0.835409188061
# [('f2709', 293, u'fat'),
#  ('f4234', 276, u'like'),
#  ('f5276', 273, u'peopl'),
#  ('f4016', 227, u'just'),
#  ('f2251', 175, u'dont'),
#  ('f7809', 164, u'white'),
#  ('f835', 138, u'becaus'),
#  ('f2996', 134, u'game'),
#  ('f2956', 126, u'fuck'),
#  ('f7876', 110, u'women'),
#  ('f930', 108, u'black'),
#  ('f3639', 105, u'im'),
#  ('f7152', 96, u'think'),
#  ('f6213', 87, u'say'),
#  ('f7769', 86, u'weight'),
#  ('f4845', 85, u'nigger'),
#  ('f7718', 81, u'want'),
#  ('f3966', 81, u'jew'),
#  ('f4361', 80, u'make'),
#  ('f7196', 77, u'time')]
